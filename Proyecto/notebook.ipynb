# %% [markdown]
# # Relación entre arrestos de personas de distintas razas y la cantidad de arrestos por estado en EEUU, entre 2018 y 2020.

# %% [markdown]
# 0. trabajo datos

# %%
import pandas as pd
import geopandas as gpd
import json
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %%
# https://www.fbi.gov/services/cjis/ucr/publications : Dataframe (18, 19) * las del 2020 esta solo el dataframe por raza
# 29 Numero de arrestos por ofensa
# 43- 49 - 55 - 61 - 67 numero de arrestos por raza
# 69 numero de arrestos por estado sobre/bajo 18 años

import requests
import os
lista_anos = [2019,2018,2017]
lista_numeros_tablas = [29, '55a' ,69]

try:
    for ano in lista_anos:
        os.makedirs(f'Data_fbi_ucr/{ano}_datos')
        for num_tabla in lista_numeros_tablas:
            dls = f"https://ucr.fbi.gov/crime-in-the-u.s/{ano}/crime-in-the-u.s.-{ano}/tables/table-{num_tabla if num_tabla != '55a' else 55}/table-{num_tabla}.xls/output.xls"
            resp = requests.get(dls)
            
            with open(f'Data_fbi_ucr/{ano}_datos/tabla_{num_tabla}.xls', 'wb') as output:
                output.write(resp.content)
except FileExistsError:
    print('ya existen estos archivos')
# Out:
# ya existen estos archivos

# %%
tabla_55a_2019 =  pd.read_excel('Data_fbi_ucr/2019_datos/tabla_55a.xls')
tabla_55a_2019 = tabla_55a_2019.rename(columns=tabla_55a_2019.iloc[6]).iloc[7:].reset_index().drop(columns=['index'])
tabla_55a_2019.head()
# Out:
#                         Offense charged    Total   White  \
# 0                                 TOTAL  1360157  975178
# 1  Murder and nonnegligent manslaughter     1687     966
# 2                                 Rape3     3387    2571
# 3                               Robbery     7898    3512
# 4                    Aggravated assault    48642   33696
#
#   Black or\nAfrican\nAmerican American\nIndian or\nAlaska\nNative  Asian  \
# 0                      350940                               11505  17866
# 1                         686                                  14     11
# 2                         736                                  14     50
# 3                        4240                                  32     79
# 4                       13657                                 392    729
#
#   Native\nHawaiian\nor Other\nPacific\nIslander Total White  \
# 0                                          4668   100  71.7
# 1                                            10   100  57.3
# 2                                            16   100  75.9
# 3                                            35   100  44.5
# 4                                           168   100  69.3
#
#   Black or\nAfrican\nAmerican American\nIndian or\nAlaska\nNative Asian  \
# 0                        25.8                                 0.8   1.3
# 1                        40.7                                 0.8   0.7
# 2                        21.7                                 0.4   1.5
# 3                        53.7                                 0.4     1
# 4                        28.1                                 0.8   1.5
#
#   Native\nHawaiian\nor Other\nPacific\nIslander   Total2 Hispanic\nor\nLatino  \
# 0                                           0.3  1165073               217727
# 1                                           0.6     1264                  303
# 2                                           0.5     2880                  766
# 3                                           0.4     6985                 1366
# 4                                           0.3    42154                 9417
#
#   Not\nHispanic\nor Latino Total Hispanic\nor\nLatino Not\nHispanic\nor Latino
# 0                   947346   100                 18.7                     81.3
# 1                      961   100                   24                       76
# 2                     2114   100                 26.6                     73.4
# 3                     5619   100                 19.6                     80.4
# 4                    32737   100                 22.3                     77.7

# %%
tabla_55a_2018 =  pd.read_excel('Data_fbi_ucr/2018_datos/tabla_55a.xls')
tabla_55a_2018 = tabla_55a_2018.rename(columns=tabla_55a_2018.iloc[6]).iloc[7:].reset_index().drop(columns=['index'])
tabla_55a_2018.head()
# Out:
#                         Offense charged    Total    White  \
# 0                                 TOTAL  1524774  1086539
# 1  Murder and nonnegligent manslaughter     1755      952
# 2                                 Rape3     3710     2835
# 3                               Robbery     9408     4226
# 4                    Aggravated assault    56315    38833
#
#   Black or\nAfrican\nAmerican American\nIndian or\nAlaska\nNative  Asian  \
# 0                      400923                               14369  18412
# 1                         780                                   6     14
# 2                         805                                  17     36
# 3                        5046                                  45     65
# 4                       16099                                 489    722
#
#   Native\nHawaiian\nor Other\nPacific\nIslander Total White  \
# 0                                          4531   100  71.3
# 1                                             3   100  54.2
# 2                                            17   100  76.4
# 3                                            26   100  44.9
# 4                                           172   100    69
#
#   Black or\nAfrican\nAmerican American\nIndian or\nAlaska\nNative Asian  \
# 0                        26.3                                 0.9   1.2
# 1                        44.4                                 0.3   0.8
# 2                        21.7                                 0.5     1
# 3                        53.6                                 0.5   0.7
# 4                        28.6                                 0.9   1.3
#
#   Native\nHawaiian\nor Other\nPacific\nIslander   Total2 Hispanic\nor\nLatino  \
# 0                                           0.3  1239300               220086
# 1                                           0.2     1356                  301
# 2                                           0.5     2978                  731
# 3                                           0.3     7898                 1464
# 4                                           0.3    46236                10184
#
#   Not\nHispanic\nor Latino Total Hispanic\nor\nLatino Not\nHispanic\nor Latino
# 0                  1019214   100                 17.8                     82.2
# 1                     1055   100                 22.2                     77.8
# 2                     2247   100                 24.5                     75.5
# 3                     6434   100                 18.5                     81.5
# 4                    36052   100                   22                       78

# %%
# usar api fbi
# codigo de todas los estados : https://api.usa.gov/crime/fbi/sapi/api/states?API_KEY=iiHnOKfno2Mgkt5AynpvPpUQTEyxE77jo1RU8PIv&size=100
# arrestos en la region por raza: https://api.usa.gov/crime/fbi/sapi/api/arrest/states/CA/all/race/2020/2020?API_KEY=iiHnOKfno2Mgkt5AynpvPpUQTEyxE77jo1RU8PIv

# %%
# extraemos los codigos de todos los estados
key = '1jL8OaKHoKG21Thdsnx6ep5Zi9qaLidKUT4jIIyu'
url_codes = f'https://api.usa.gov/crime/fbi/sapi/api/states?API_KEY={key}&size=100'

r=requests.get(url_codes)
r.json()
# Out:
# {'results': [{'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'region_code': 4,
#    'state_fips_code': 2},
#   {'state_id': 2,
#    'state_name': 'Alabama',
#    'state_abbr': 'AL',
#    'region_code': 3,
#    'state_fips_code': 1},
#   {'state_id': 3,
#    'state_name': 'Arkansas',
#    'state_abbr': 'AR',
#    'region_code': 3,
#    'state_fips_code': 5},
#   {'state_id': 4,
#    'state_name': 'American Samoa',
#    'state_abbr': 'AS',
#    'region_code': 99,
#    'state_fips_code': 60},
#   {'state_id': 5,
#    'state_name': 'Arizona',
#    'state_abbr': 'AZ',
#    'region_code': 4,
#    'state_fips_code': 4},
#   {'state_id': 6,
#    'state_name': 'California',
#    'state_abbr': 'CA',
#    'region_code': 4,
#    'state_fips_code': 6},
#   {'state_id': 7,
#    'state_name': 'Colorado',
#    'state_abbr': 'CO',
#    'region_code': 4,
#    'state_fips_code': 8},
#   {'state_id': 8,
#    'state_name': 'Connecticut',
#    'state_abbr': 'CT',
#    'region_code': 1,
#    'state_fips_code': 9},
#   {'state_id': 9,
#    'state_name': 'Canal Zone',
#    'state_abbr': 'CZ',
#    'region_code': 99,
#    'state_fips_code': None},
#   {'state_id': 10,
#    'state_name': 'District of Columbia',
#    'state_abbr': 'DC',
#    'region_code': 3,
#    'state_fips_code': 11},
#   {'state_id': 11,
#    'state_name': 'Delaware',
#    'state_abbr': 'DE',
#    'region_code': 3,
#    'state_fips_code': 10},
#   {'state_id': 12,
#    'state_name': 'Florida',
#    'state_abbr': 'FL',
#    'region_code': 3,
#    'state_fips_code': 12},
#   {'state_id': 13,
#    'state_name': 'Georgia',
#    'state_abbr': 'GA',
#    'region_code': 3,
#    'state_fips_code': 13},
#   {'state_id': 15,
#    'state_name': 'Hawaii',
#    'state_abbr': 'HI',
#    'region_code': 4,
#    'state_fips_code': 15},
#   {'state_id': 16,
#    'state_name': 'Iowa',
#    'state_abbr': 'IA',
#    'region_code': 2,
#    'state_fips_code': 19},
#   {'state_id': 17,
#    'state_name': 'Idaho',
#    'state_abbr': 'ID',
#    'region_code': 4,
#    'state_fips_code': 16},
#   {'state_id': 18,
#    'state_name': 'Illinois',
#    'state_abbr': 'IL',
#    'region_code': 2,
#    'state_fips_code': 17},
#   {'state_id': 19,
#    'state_name': 'Indiana',
#    'state_abbr': 'IN',
#    'region_code': 2,
#    'state_fips_code': 18},
#   {'state_id': 20,
#    'state_name': 'Kansas',
#    'state_abbr': 'KS',
#    'region_code': 2,
#    'state_fips_code': 20},
#   {'state_id': 21,
#    'state_name': 'Kentucky',
#    'state_abbr': 'KY',
#    'region_code': 3,
#    'state_fips_code': 21},
#   {'state_id': 22,
#    'state_name': 'Louisiana',
#    'state_abbr': 'LA',
#    'region_code': 3,
#    'state_fips_code': 22},
#   {'state_id': 23,
#    'state_name': 'Massachusetts',
#    'state_abbr': 'MA',
#    'region_code': 1,
#    'state_fips_code': 25},
#   {'state_id': 24,
#    'state_name': 'Maryland',
#    'state_abbr': 'MD',
#    'region_code': 3,
#    'state_fips_code': 24},
#   {'state_id': 25,
#    'state_name': 'Maine',
#    'state_abbr': 'ME',
#    'region_code': 1,
#    'state_fips_code': 23},
#   {'state_id': 26,
#    'state_name': 'Michigan',
#    'state_abbr': 'MI',
#    'region_code': 2,
#    'state_fips_code': 26},
#   {'state_id': 27,
#    'state_name': 'Minnesota',
#    'state_abbr': 'MN',
#    'region_code': 2,
#    'state_fips_code': 27},
#   {'state_id': 28,
#    'state_name': 'Missouri',
#    'state_abbr': 'MO',
#    'region_code': 2,
#    'state_fips_code': 29},
#   {'state_id': 29,
#    'state_name': 'Mississippi',
#    'state_abbr': 'MS',
#    'region_code': 3,
#    'state_fips_code': 28},
#   {'state_id': 30,
#    'state_name': 'Montana',
#    'state_abbr': 'MT',
#    'region_code': 4,
#    'state_fips_code': 30},
#   {'state_id': 31,
#    'state_name': 'Nebraska',
#    'state_abbr': 'NE',
#    'region_code': 2,
#    'state_fips_code': 31},
#   {'state_id': 32,
#    'state_name': 'North Carolina',
#    'state_abbr': 'NC',
#    'region_code': 3,
#    'state_fips_code': 37},
#   {'state_id': 33,
#    'state_name': 'North Dakota',
#    'state_abbr': 'ND',
#    'region_code': 2,
#    'state_fips_code': 38},
#   {'state_id': 34,
#    'state_name': 'New Hampshire',
#    'state_abbr': 'NH',
#    'region_code': 1,
#    'state_fips_code': 33},
#   {'state_id': 35,
#    'state_name': 'New Jersey',
#    'state_abbr': 'NJ',
#    'region_code': 1,
#    'state_fips_code': 34},
#   {'state_id': 36,
#    'state_name': 'New Mexico',
#    'state_abbr': 'NM',
#    'region_code': 4,
#    'state_fips_code': 35},
#   {'state_id': 37,
#    'state_name': 'Nevada',
#    'state_abbr': 'NV',
#    'region_code': 4,
#    'state_fips_code': 32},
#   {'state_id': 38,
#    'state_name': 'New York',
#    'state_abbr': 'NY',
#    'region_code': 1,
#    'state_fips_code': 36},
#   {'state_id': 39,
#    'state_name': 'Ohio',
#    'state_abbr': 'OH',
#    'region_code': 2,
#    'state_fips_code': 39},
#   {'state_id': 40,
#    'state_name': 'Oklahoma',
#    'state_abbr': 'OK',
#    'region_code': 3,
#    'state_fips_code': 40},
#   {'state_id': 41,
#    'state_name': 'Oregon',
#    'state_abbr': 'OR',
#    'region_code': 4,
#    'state_fips_code': 41},
#   {'state_id': 42,
#    'state_name': 'Pennsylvania',
#    'state_abbr': 'PA',
#    'region_code': 1,
#    'state_fips_code': 42},
#   {'state_id': 43,
#    'state_name': 'Puerto Rico',
#    'state_abbr': 'PR',
#    'region_code': 1,
#    'state_fips_code': 72},
#   {'state_id': 44,
#    'state_name': 'Rhode Island',
#    'state_abbr': 'RI',
#    'region_code': 1,
#    'state_fips_code': 44},
#   {'state_id': 45,
#    'state_name': 'South Carolina',
#    'state_abbr': 'SC',
#    'region_code': 3,
#    'state_fips_code': 45},
#   {'state_id': 46,
#    'state_name': 'South Dakota',
#    'state_abbr': 'SD',
#    'region_code': 2,
#    'state_fips_code': 46},
#   {'state_id': 47,
#    'state_name': 'Tennessee',
#    'state_abbr': 'TN',
#    'region_code': 3,
#    'state_fips_code': 47},
#   {'state_id': 48,
#    'state_name': 'Texas',
#    'state_abbr': 'TX',
#    'region_code': 3,
#    'state_fips_code': 48},
#   {'state_id': 49,
#    'state_name': 'Utah',
#    'state_abbr': 'UT',
#    'region_code': 4,
#    'state_fips_code': 49},
#   {'state_id': 51,
#    'state_name': 'Virginia',
#    'state_abbr': 'VA',
#    'region_code': 3,
#    'state_fips_code': 51},
#   {'state_id': 52,
#    'state_name': 'Vermont',
#    'state_abbr': 'VT',
#    'region_code': 1,
#    'state_fips_code': 50},
#   {'state_id': 53,
#    'state_name': 'Washington',
#    'state_abbr': 'WA',
#    'region_code': 4,
#    'state_fips_code': 53},
#   {'state_id': 54,
#    'state_name': 'Wisconsin',
#    'state_abbr': 'WI',
#    'region_code': 2,
#    'state_fips_code': 55},
#   {'state_id': 55,
#    'state_name': 'West Virginia',
#    'state_abbr': 'WV',
#    'region_code': 3,
#    'state_fips_code': 54},
#   {'state_id': 56,
#    'state_name': 'Wyoming',
#    'state_abbr': 'WY',
#    'region_code': 4,
#    'state_fips_code': 56},
#   {'state_id': 57,
#    'state_name': 'Mariana Islands',
#    'state_abbr': 'MP',
#    'region_code': 0,
#    'state_fips_code': 69},
#   {'state_id': 99,
#    'state_name': 'Other',
#    'state_abbr': 'OT',
#    'region_code': 99,
#    'state_fips_code': 99},
#   {'state_id': 50,
#    'state_name': 'US Virgin Islands',
#    'state_abbr': 'VI',
#    'region_code': 0,
#    'state_fips_code': 78},
#   {'state_id': 14,
#    'state_name': 'Guam',
#    'state_abbr': 'GM',
#    'region_code': 0,
#    'state_fips_code': 66}],
#  'pagination': {'count': 58, 'page': 0, 'pages': 1, 'per_page': 100}}

# %%
df_codes=pd.json_normalize(r.json(),record_path='results')
df_codes
# Out:
#     state_id            state_name state_abbr  region_code  state_fips_code
# 0          1                Alaska         AK            4              2.0
# 1          2               Alabama         AL            3              1.0
# 2          3              Arkansas         AR            3              5.0
# 3          4        American Samoa         AS           99             60.0
# 4          5               Arizona         AZ            4              4.0
# 5          6            California         CA            4              6.0
# 6          7              Colorado         CO            4              8.0
# 7          8           Connecticut         CT            1              9.0
# 8          9            Canal Zone         CZ           99              NaN
# 9         10  District of Columbia         DC            3             11.0
# 10        11              Delaware         DE            3             10.0
# 11        12               Florida         FL            3             12.0
# 12        13               Georgia         GA            3             13.0
# 13        15                Hawaii         HI            4             15.0
# 14        16                  Iowa         IA            2             19.0
# 15        17                 Idaho         ID            4             16.0
# 16        18              Illinois         IL            2             17.0
# 17        19               Indiana         IN            2             18.0
# 18        20                Kansas         KS            2             20.0
# 19        21              Kentucky         KY            3             21.0
# 20        22             Louisiana         LA            3             22.0
# 21        23         Massachusetts         MA            1             25.0
# 22        24              Maryland         MD            3             24.0
# 23        25                 Maine         ME            1             23.0
# 24        26              Michigan         MI            2             26.0
# 25        27             Minnesota         MN            2             27.0
# 26        28              Missouri         MO            2             29.0
# 27        29           Mississippi         MS            3             28.0
# 28        30               Montana         MT            4             30.0
# 29        31              Nebraska         NE            2             31.0
# 30        32        North Carolina         NC            3             37.0
# 31        33          North Dakota         ND            2             38.0
# 32        34         New Hampshire         NH            1             33.0
# 33        35            New Jersey         NJ            1             34.0
# 34        36            New Mexico         NM            4             35.0
# 35        37                Nevada         NV            4             32.0
# 36        38              New York         NY            1             36.0
# 37        39                  Ohio         OH            2             39.0
# 38        40              Oklahoma         OK            3             40.0
# 39        41                Oregon         OR            4             41.0
# 40        42          Pennsylvania         PA            1             42.0
# 41        43           Puerto Rico         PR            1             72.0
# 42        44          Rhode Island         RI            1             44.0
# 43        45        South Carolina         SC            3             45.0
# 44        46          South Dakota         SD            2             46.0
# 45        47             Tennessee         TN            3             47.0
# 46        48                 Texas         TX            3             48.0
# 47        49                  Utah         UT            4             49.0
# 48        51              Virginia         VA            3             51.0
# 49        52               Vermont         VT            1             50.0
# 50        53            Washington         WA            4             53.0
# 51        54             Wisconsin         WI            2             55.0
# 52        55         West Virginia         WV            3             54.0
# 53        56               Wyoming         WY            4             56.0
# 54        57       Mariana Islands         MP            0             69.0
# 55        99                 Other         OT           99             99.0
# 56        50     US Virgin Islands         VI            0             78.0
# 57        14                  Guam         GM            0             66.0

# %%
# Solo vamos a considerar los 50 estados principales
df_codes = df_codes.drop([3,8,9, 41,54, 55, 56, 57])

# %%
codigos_estados = df_codes[['state_abbr']].values

# %%
# iterar en cada estado para estraer su dataframe de arrestos por raza del 2018 al 2020
lista_anos = [2020,2019,2018,2017]

try:
    for estado in codigos_estados:
        estado = estado[0]
        os.makedirs(f'Data_fbi_arrestos_2017_2020/{estado}_datos_arrestos_raza')
        dls = f"https://api.usa.gov/crime/fbi/sapi/api/arrest/states/{estado}/all/race/2017/2020?API_KEY={key}"
        resp = requests.get(dls)
        with open(f'Data_fbi_arrestos_2017_2020/{estado}_datos_arrestos_raza/datos_{estado}.json', 'wb') as output:
            output.write(resp.content)
except FileExistsError:
    print('ya existen estos archivos')
# Out:
# ya existen estos archivos

# %%
df_estados_razas = dict()

for estado in codigos_estados:
    estado = estado[0]
    with open(f'Data_fbi_arrestos_2017_2020\{estado}_datos_arrestos_raza\datos_{estado}.json', 'r') as file:
        params = json.load(file)
        df_estados_razas[estado] = pd.DataFrame.from_dict(params['data'])

# %%
df_estados_razas['CA']
# Out:
#      value  data_year  month_num                               key
# 0    26504       2017          0                             Asian
# 1    26954       2018          0                             Asian
# 2    26003       2019          0                             Asian
# 3    21181       2020          0                             Asian
# 4     4246       2017          0                   Native Hawaiian
# 5     4429       2018          0                   Native Hawaiian
# 6     4348       2019          0                   Native Hawaiian
# 7     3434       2020          0                   Native Hawaiian
# 8   180253       2017          0         Black or African American
# 9   176483       2018          0         Black or African American
# 10  168555       2019          0         Black or African American
# 11  134559       2020          0         Black or African American
# 12    6170       2017          0  American Indian or Alaska Native
# 13    5909       2018          0  American Indian or Alaska Native
# 14    5714       2019          0  American Indian or Alaska Native
# 15    4544       2020          0  American Indian or Alaska Native
# 16  881115       2017          0                             White
# 17  879540       2018          0                             White
# 18  840139       2019          0                             White
# 19  684148       2020          0                             White
# 20       0       2017          0                           Unknown
# 21       0       2018          0                           Unknown
# 22       0       2019          0                           Unknown
# 23       0       2020          0                           Unknown

# %% [markdown]
# 1. cantidad de arrstos por estado

# %%
# cual es el estado con mayor numero de arrestos por raza y por año
df_2020_arrestos_white = pd.DataFrame()
df_2019_arrestos_white = pd.DataFrame()
df_2018_arrestos_white = pd.DataFrame()

df_2020_arrestos_black = pd.DataFrame()
df_2019_arrestos_black = pd.DataFrame()
df_2018_arrestos_black = pd.DataFrame()


for estado in codigos_estados:
    estado = estado[0]
    df_estado = df_estados_razas[estado]
    df_estado['estado'] = estado
    df_2020_arrestos_white = df_2020_arrestos_white.append(df_estado.loc[19], ignore_index= True)
    df_2019_arrestos_white = df_2019_arrestos_white.append(df_estado.loc[18], ignore_index= True)
    df_2018_arrestos_white = df_2018_arrestos_white.append(df_estado.loc[17], ignore_index= True)

    df_2020_arrestos_black = df_2020_arrestos_black.append(df_estado.loc[11], ignore_index= True)
    df_2019_arrestos_black = df_2019_arrestos_black.append(df_estado.loc[10], ignore_index= True)
    df_2018_arrestos_black = df_2018_arrestos_black.append(df_estado.loc[9], ignore_index= True)

# %%
# Ordenamos los dataframes para tener un df final con todo lo que necesitemos por año
df_2020_arrestos = pd.DataFrame()

df_2020_arrestos = df_2020_arrestos.append(df_2020_arrestos_white, ignore_index= True )
df_2020_arrestos = df_2020_arrestos.append(df_2020_arrestos_black, ignore_index= True )
df_2020_arrestos = df_2020_arrestos.groupby(['estado'])
value_ = df_2020_arrestos['value'].apply(list)
key_ = df_2020_arrestos['key'].apply(list)
year_ = df_2020_arrestos['data_year'].apply(list)
df_2020_arrestos = pd.merge(value_, key_, on= 'estado')
df_2020_arrestos = pd.merge(df_2020_arrestos, year_, on= 'estado')
df_2020_arrestos['arrestos_w_2020'] = df_2020_arrestos.apply(lambda row: row.value[0], axis=1)
df_2020_arrestos['arrestos_b_2020'] = df_2020_arrestos.apply(lambda row: row.value[1], axis=1)
df_2020_arrestos['arrestos_total_2020'] = df_2020_arrestos.apply(lambda row: row.arrestos_b_2020 + row.arrestos_w_2020, axis=1)



df_2019_arrestos = pd.DataFrame()

df_2019_arrestos = df_2019_arrestos.append(df_2019_arrestos_white, ignore_index= True )
df_2019_arrestos = df_2019_arrestos.append(df_2019_arrestos_black, ignore_index= True )
df_2019_arrestos = df_2019_arrestos.groupby(['estado'])
value_ = df_2019_arrestos['value'].apply(list)
key_ = df_2019_arrestos['key'].apply(list)
year_ = df_2019_arrestos['data_year'].apply(list)
df_2019_arrestos = pd.merge(value_, key_, on= 'estado')
df_2019_arrestos = pd.merge(df_2019_arrestos, year_, on= 'estado')
df_2019_arrestos['arrestos_w_2019'] = df_2019_arrestos.apply(lambda row: row.value[0], axis=1)
df_2019_arrestos['arrestos_b_2019'] = df_2019_arrestos.apply(lambda row: row.value[1], axis=1)
df_2019_arrestos['arrestos_total_2019'] = df_2019_arrestos.apply(lambda row: row.arrestos_b_2019 + row.arrestos_w_2019, axis=1)


df_2018_arrestos = pd.DataFrame()

df_2018_arrestos = df_2018_arrestos.append(df_2018_arrestos_white, ignore_index= True )
df_2018_arrestos = df_2018_arrestos.append(df_2018_arrestos_black, ignore_index= True )
df_2018_arrestos = df_2018_arrestos.groupby(['estado'])
value_ = df_2018_arrestos['value'].apply(list)
key_ = df_2018_arrestos['key'].apply(list)
year_ = df_2018_arrestos['data_year'].apply(list)
df_2018_arrestos = pd.merge(value_, key_, on= 'estado')
df_2018_arrestos = pd.merge(df_2018_arrestos, year_, on= 'estado')
df_2018_arrestos['arrestos_w_2018'] = df_2018_arrestos.apply(lambda row: row.value[0], axis=1)
df_2018_arrestos['arrestos_b_2018'] = df_2018_arrestos.apply(lambda row: row.value[1], axis=1)
df_2018_arrestos['arrestos_total_2018'] = df_2018_arrestos.apply(lambda row: row.arrestos_b_2018 + row.arrestos_w_2018, axis=1)


df_2020_arrestos = df_2020_arrestos.drop(columns=['value','key','data_year'])
df_2019_arrestos = df_2019_arrestos.drop(columns=['value','key','data_year'])
# WV              29695.0           4293.0              33988.0
# WY              22984.0           1161.0              24145.0

# %% [markdown]
# Ahora extraemos los datos de poblacion los cuales fueron extraidos de forma de descarga ya que solo estaban disponibles de esta forma en:

# %%
pobl_2018 = pd.read_csv('data_poblacion\poblacion_2018.csv', sep=',')
pobl_2019 = pd.read_csv('data_poblacion\poblacion_2019.csv', sep=',')
pobl_2020 = pd.read_csv('data_poblacion\poblacion_2020.csv', sep=',')
pobl_2018.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  192117000.0  38655700.0  58483600.0  17844800.0
# 1        Alabama    3115600.0   1257300.0    204800.0     63800.0
# 2         Alaska     426100.0     20700.0     50200.0     43200.0
# 3        Arizona    3815100.0    297000.0   2213600.0    227200.0
# 4       Arkansas    2110400.0    436900.0    224900.0     44200.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2082800.0                                519500.0
# 1                        19000.0                                     NaN
# 2                       110300.0                                  7400.0
# 3                       271900.0                                 12000.0
# 4                        17000.0                                  8200.0
#
#    Multiple Races        Total  Footnotes
# 0       8795000.0  318498500.0        1.0
# 1         90700.0    4752600.0        NaN
# 2         51100.0     709100.0        NaN
# 3        167400.0    7004300.0        NaN
# 4         79700.0    2921300.0        NaN

# %%
# ahora solo necesitamos la info de la poblacion White, Black, Total
pobl_2018 = pobl_2018[['Location','White', 'Black','Total']]
pobl_2019 = pobl_2019[['Location','White', 'Black','Total']]
pobl_2020 = pobl_2020[['Location','White', 'Black','Total']]
pobl_2020.head()
# Out:
#         Location        White       Black        Total
# 0  United States  194000000.0  40439900.0  325637800.0
# 1        Alabama    3201500.0   1308800.0    4885700.0
# 2         Alaska     399000.0     22600.0     706100.0
# 3        Arizona    3977400.0    373300.0    7467800.0
# 4       Arkansas    2126500.0    440200.0    2977500.0

# %%
df_poblacion = pd.merge(pobl_2020, pobl_2019, on='Location')
df_poblacion.rename(columns={
    'White_x': 'poblacion_w_2020',
    'Black_x': 'poblacion_b_2020',
    'Total_x': 'total_2020',
    'White_y':'poblacion_w_2019',
    'Black_y':'poblacion_b_2019',
    'Total_y': 'total_2019'}, inplace=True)
df_poblacion = pd.merge(df_poblacion, pobl_2018, on='Location')
df_poblacion.rename(columns={
    'White': 'poblacion_w_2018',
    'Black': 'poblacion_b_2018',
    'Total': 'total_2018',}, inplace=True)
df_poblacion
# Out:
#                                              Location  poblacion_w_2020  \
# 0                                       United States       194000000.0
# 1                                             Alabama         3201500.0
# 2                                              Alaska          399000.0
# 3                                             Arizona         3977400.0
# 4                                            Arkansas         2126500.0
# ..                                                ...               ...
# 62                                                NaN               NaN
# 63                                                NaN               NaN
# 64                                                NaN               NaN
# 65                                                NaN               NaN
# 66  Persons of Hispanic origin may be of any race;...               NaN
#
#     poblacion_b_2020   total_2020  poblacion_w_2019  poblacion_b_2019  \
# 0         40439900.0  325637800.0       191757100.0        38872200.0
# 1          1308800.0    4885700.0         3117200.0         1263500.0
# 2            22600.0     706100.0          421100.0           15200.0
# 3           373300.0    7467800.0         3843700.0          306600.0
# 4           440200.0    2977500.0         2108400.0          444200.0
# ..               ...          ...               ...               ...
# 62               NaN          NaN               NaN               NaN
# 63               NaN          NaN               NaN               NaN
# 64               NaN          NaN               NaN               NaN
# 65               NaN          NaN               NaN               NaN
# 66               NaN          NaN               NaN               NaN
#
#      total_2019  poblacion_w_2018  poblacion_b_2018   total_2018
# 0   319249300.0       192117000.0        38655700.0  318498500.0
# 1     4767100.0         3115600.0         1257300.0    4752600.0
# 2      701700.0          426100.0           20700.0     709100.0
# 3     7098000.0         3815100.0          297000.0    7004300.0
# 4     2922500.0         2110400.0          436900.0    2921300.0
# ..          ...               ...               ...          ...
# 62          NaN               NaN               NaN          NaN
# 63          NaN               NaN               NaN          NaN
# 64          NaN               NaN               NaN          NaN
# 65          NaN               NaN               NaN          NaN
# 66          NaN               NaN               NaN          NaN
#
# [67 rows x 10 columns]

# %%
# ahora le añadimos los codigos de comunas state_name	state_abbr
df_poblacion = pd.merge(df_codes[['state_name', 'state_abbr']], df_poblacion, left_on='state_name', right_on='Location'   )
df_poblacion
# Out:
#         state_name state_abbr        Location  poblacion_w_2020  \
# 0           Alaska         AK          Alaska          399000.0
# 1          Alabama         AL         Alabama         3201500.0
# 2         Arkansas         AR        Arkansas         2126500.0
# 3          Arizona         AZ         Arizona         3977400.0
# 4       California         CA      California        14335200.0
# 5         Colorado         CO        Colorado         3927100.0
# 6      Connecticut         CT     Connecticut         2226300.0
# 7         Delaware         DE        Delaware          597500.0
# 8          Florida         FL         Florida        11167500.0
# 9          Georgia         GA         Georgia         5280100.0
# 10          Hawaii         HI          Hawaii          277700.0
# 11            Iowa         IA            Iowa         2665500.0
# 12           Idaho         ID           Idaho         1469100.0
# 13        Illinois         IL        Illinois         7634800.0
# 14         Indiana         IN         Indiana         5247000.0
# 15          Kansas         KS          Kansas         2153300.0
# 16        Kentucky         KY        Kentucky         3598500.0
# 17       Louisiana         LA       Louisiana         2605700.0
# 18   Massachusetts         MA   Massachusetts         4777500.0
# 19        Maryland         MD        Maryland         2949600.0
# 20           Maine         ME           Maine         1271800.0
# 21        Michigan         MI        Michigan         7384600.0
# 22       Minnesota         MN       Minnesota         4320400.0
# 23        Missouri         MO        Missouri         4684900.0
# 24     Mississippi         MS     Mississippi         1686900.0
# 25         Montana         MT         Montana          975100.0
# 26        Nebraska         NE        Nebraska         1497600.0
# 27  North Carolina         NC  North Carolina         6181900.0
# 28    North Dakota         ND    North Dakota          621400.0
# 29   New Hampshire         NH   New Hampshire         1215300.0
# 30      New Jersey         NJ      New Jersey         4734100.0
# 31      New Mexico         NM      New Mexico          832500.0
# 32          Nevada         NV          Nevada         1589300.0
# 33        New York         NY        New York        10553000.0
# 34            Ohio         OH            Ohio         9036700.0
# 35        Oklahoma         OK        Oklahoma         2393600.0
# 36          Oregon         OR          Oregon         3147000.0
# 37    Pennsylvania         PA    Pennsylvania         9524100.0
# 38    Rhode Island         RI    Rhode Island          795300.0
# 39  South Carolina         SC  South Carolina         3222500.0
# 40    South Dakota         SD    South Dakota          721200.0
df_final['porcentaje_arresto_w_2019'] = df_final.apply(lambda row: row.arrestos_w_2019/row.arrestos_total_2019  , axis=1)
df_final['porcentaje_arresto_w_2018'] = df_final.apply(lambda row: row.arrestos_w_2018/row.arrestos_total_2018  , axis=1)

df_final['porcentaje_arresto_b_2020'] = df_final.apply(lambda row: row.arrestos_b_2020/row.arrestos_total_2020  , axis=1)
df_final['porcentaje_arresto_b_2019'] = df_final.apply(lambda row: row.arrestos_b_2019/row.arrestos_total_2019  , axis=1)
df_final['porcentaje_arresto_b_2018'] = df_final.apply(lambda row: row.arrestos_b_2018/row.arrestos_total_2018  , axis=1)

df_final['porcentaje_w_2020'] = df_final.apply(lambda row: row.poblacion_w_2020/row.total_2020  , axis=1)
df_final['porcentaje_w_2019'] = df_final.apply(lambda row: row.poblacion_w_2019/row.total_2019  , axis=1)
df_final['porcentaje_w_2018'] = df_final.apply(lambda row: row.poblacion_w_2018/row.total_2018  , axis=1)

df_final['porcentaje_b_2020'] = df_final.apply(lambda row: row.poblacion_b_2020/row.total_2020  , axis=1)
df_final['porcentaje_b_2019'] = df_final.apply(lambda row: row.poblacion_b_2019/row.total_2019  , axis=1)
df_final['porcentaje_b_2018'] = df_final.apply(lambda row: row.poblacion_b_2018/row.total_2018  , axis=1)

# df_final = pd.merge(df_final, states, left_on='state_abbr', right_on='STUSPS').drop(columns=['Location', 'state_name']).set_index('STUSPS')
df_final
# Out:
#             arrestos_w_2020  arrestos_b_2020  arrestos_total_2020  \
# state_abbr
# AK                  12588.0           1979.0              14567.0
# AL                   2558.0           1552.0               4110.0
# AR                  64222.0          30766.0              94988.0
# AZ                 140616.0          27418.0             168034.0
# CA                 684148.0         134559.0             818707.0
# CO                 131484.0          19648.0             151132.0
# CT                  43678.0          22975.0              66653.0
# DE                  12442.0          11988.0              24430.0
# GA                  57913.0          56461.0             114374.0
# HI                   8574.0           1188.0               9762.0
# IA                  60365.0          16600.0              76965.0
# ID                  37769.0           1287.0              39056.0
# IL                   2201.0           3311.0               5512.0
# IN                  52460.0          26179.0              78639.0
# KS                  43800.0          11281.0              55081.0
# KY                 118159.0          21166.0             139325.0
# LA                  54961.0          74621.0             129582.0
# MA                  62011.0          15830.0              77841.0
# MD                   4769.0           7791.0              12560.0
# ME                  29193.0           2019.0              31212.0
# MI                  94453.0          60417.0             154870.0
# MN                  65528.0          30319.0              95847.0
# MO                  98096.0          44098.0             142194.0
# MS                  20387.0          24822.0              45209.0
# MT                  18128.0            721.0              18849.0
# NC                 107242.0          87013.0             194255.0
# ND                  20272.0           3248.0              23520.0
# NE                  26252.0           8612.0              34864.0
# NH                  32780.0           2084.0              34864.0
# NJ                  94420.0          70847.0             165267.0
# NM                  25500.0           2745.0              28245.0
# NV                  70413.0          34457.0             104870.0
# NY                 100412.0          50638.0             151050.0
# OH                  87420.0          46303.0             133723.0
# OK                  57300.0          19134.0              76434.0
# OR                  86878.0           7835.0              94713.0
# PA                   1640.0            576.0               2216.0
# RI                  14766.0           4640.0              19406.0
# SC                  76549.0          57265.0             133814.0
# HI                   0.015058
# IA                   0.033466
# ID                   0.005408
# IL                   0.135484
# IN                   0.092584
# KS                   0.053540
# KY                   0.076013
# LA                   0.316354
# MA                   0.069896
# MD                   0.293044
# ME                   0.013390
# MI                   0.135302
# MN                   0.064875
# MO                   0.113000
# MS                   0.376710
# MT                   0.003578
# NC                   0.208634
# ND                   0.030386
# NE                   0.043930
# NH                   0.011142
# NJ                   0.126061
# NM                   0.018139
# NV                   0.086713
# NY                   0.141159
# OH                   0.121188
# OK                   0.070150
# OR                   0.018074
# PA                   0.102905
# RI                   0.056213
# SC                   0.263337
# SD                   0.021798
# TN                   0.165128
# TX                   0.116040
# UT                   0.011526
# VA                   0.185698
# VT                   0.010989
# WA                   0.036469
# WI                   0.061701
# WV                   0.036124
# WY                   0.004819
#
# [49 rows x 32 columns]

# %%
df_final.keys()
# Out:
# Index(['arrestos_w_2020', 'arrestos_b_2020', 'arrestos_total_2020',
#        'arrestos_w_2019', 'arrestos_b_2019', 'arrestos_total_2019',
#        'arrestos_w_2018', 'arrestos_b_2018', 'arrestos_total_2018',
#        'state_name', 'Location', 'poblacion_w_2020', 'poblacion_b_2020',
#        'total_2020', 'poblacion_w_2019', 'poblacion_b_2019', 'total_2019',
#        'poblacion_w_2018', 'poblacion_b_2018', 'total_2018',
#        'porcentaje_arresto_w_2020', 'porcentaje_arresto_w_2019',
#        'porcentaje_arresto_w_2018', 'porcentaje_arresto_b_2020',
#        'porcentaje_arresto_b_2019', 'porcentaje_arresto_b_2018',
#        'porcentaje_w_2020', 'porcentaje_w_2019', 'porcentaje_w_2018',
#        'porcentaje_b_2020', 'porcentaje_b_2019', 'porcentaje_b_2018'],
#       dtype='object')

# %%
df_final = df_final.drop(columns=['Location'])

# %% [markdown]
# # Preguntas: #
# *1. ¿Cuáles son los estados con más y menos arrestos de gente blanca y afroamericana, en conjunto y por raza? (promedio entre 2018 y 2020)?*

# %%
# Para responder esta pregunta usaremos los datos de arrestos por razas de los 50 estados que estamos trabajando 
# entre 2018 y 2020

df_arrestos_totales_estados.head()
# Out:
#         arrestos_total_2020  arrestos_total_2019  arrestos_total_2018
# estado
# AK                  14567.0              15483.0              17213.0
# AL                   4110.0             140932.0             149288.0
# AR                  94988.0             129100.0             132657.0
# AZ                 168034.0             203396.0             220758.0
# CA                 818707.0            1008694.0            1056023.0

# %%
# Primero extraeremos el top estados de arrestos en total, para eso creamos una columna con el promedio de las columnas 
df_pregunta_1_a = df_arrestos_totales_estados.copy()
df_pregunta_1_a['promedio_total'] = df_arrestos_totales_estados.apply(lambda row: (row.arrestos_total_2020 + row.arrestos_total_2019 + row.arrestos_total_2018) / 3, axis=1)
df_pregunta_1_a[['promedio_total']].sort_values(by=['promedio_total'])
# Out:
#         promedio_total
# estado
# HI        12763.666667
# VT        13779.333333
# AK        15754.333333
# MT        20577.000000
# WY        21931.000000
# RI        23314.666667
# SD        23581.333333
# ND        25684.333333
# DE        27778.666667
# WV        29548.000000
# IL        33188.333333
# ME        36400.333333
# NH        42050.000000
# NM        46608.333333
# ID        47856.666667
# KS        52781.333333
# NE        53433.333333
# MS        60233.333333
# CT        84696.333333
# IA        85051.000000
# UT        85367.333333
# OK        87023.000000
# AL        98110.000000
# MA        98169.000000
# IN       108726.333333
# AR       118915.000000
# OR       119349.333333
# MN       120980.666667
# MD       126005.333333
# NV       127942.666667
# SC       150500.000000
# WA       150931.666667
# PA       162761.666667
# GA       166660.000000
# LA       168386.333333
# OH       175741.333333
# MO       181283.333333
# CO       194969.333333
# MI       196524.333333
# AZ       197396.000000
# NY       203464.333333
# WI       207056.000000
# KY       219856.000000
# NJ       227880.333333
# NC       240753.666667
# VA       247323.000000
# TN       317983.333333
# TX       643825.666667
# CA       961141.333333

# %% [markdown]
# *Asi entonces podemos concluir que los estados con menor numero de arrestos totales promedio entre gente blanca y de color en los ultimos 3 años son:*
# 1. Hawaii (HI) - 12763.66666
# 2. Vermont (VT) - 13779.333333
# 3. Alaska (AK) - 15754.333333
#
# *Y los estados con mayor numero de arrestos totales promedio entre gente blanca y de color en los ultimos 3 años son:*
#
# 1. California (CA) - 961141.333333
# 2. Texas (TX) - 643825.666667
# 3. Tennessee (TN) - 317983.333333

# %% [markdown]
# *Ahora vamos a sacar el top de la gente blanca*

# %%
# Primero extraeremos el top estados de arrestos por raza, para eso creamos una columna con el promedio de las otras columnas 
df_pregunta_1_b = df_arrestos_estados.copy()[['arrestos_w_2020', 'arrestos_w_2019' , 'arrestos_w_2018']]
df_pregunta_1_b
df_pregunta_1_b['promedio_total_blanca'] = df_pregunta_1_b.apply(lambda row: (row.arrestos_w_2020 + row.arrestos_w_2019 + row.arrestos_w_2018) / 3, axis=1)
df_pregunta_1_b[['promedio_total_blanca']].sort_values(by=['promedio_total_blanca'])
# Out:
#         promedio_total_blanca
# estado
# IL               10338.666667
# HI               11272.000000
# VT               12802.333333
# AK               13608.333333
# DE               14290.666667
# RI               17724.666667
# MT               19813.333333
# SD               20358.666667
# WY               20825.666667
# ND               22112.333333
# WV               26015.000000
# MS               26331.333333
# ME               34106.000000
# NH               39697.000000
# NE               41433.333333
# KS               42663.333333
# NM               43216.333333
# ID               46284.666667
# CT               56641.333333
# AL               58081.000000
# MD               59689.666667
# OK               66307.666667
# IA               66631.333333
# LA               71532.000000
# IN               74707.666667
# MA               78083.666667
# UT               79489.666667
# AR               80707.666667
# GA               82485.333333
# MN               84269.666667
# SC               85117.333333
# NV               87837.000000
# OR              109191.333333
# PA              115331.000000
# OH              115569.000000
# MI              125204.666667
# MO              125793.666667
# WA              127881.333333
# NJ              131393.333333
# NC              131813.666667
# NY              136538.666667
# VA              143687.333333
# WI              157361.000000
# AZ              167087.000000
# CO              170483.333333
# KY              180549.000000
# TN              225579.333333
# TX              473745.666667
# CA              801275.666667

# %% [markdown]
# *Asi entonces podemos concluir que los estados con menor numero de arrestos totales promedio entre gente blanca en los ultimos 3 años son:*
# 1. Illinois(IL) - 10338.666667
# 2. Hawaii (HI) - 11272.000000
# 3. Vermont (VT) - 12802.33333
#
# *Y los estados con mayor numero de arrestos totales promedio entre gente blanca en los ultimos 3 años son:*
#
# 1. California (CA) - 801275.666667
# 2. Texas (TX) - 643825.666667
# 3. Tennessee (TN) - 317983.333333

# %% [markdown]
# *Ahora vamos a sacar el top de la gente blanca*

# %%
# Primero extraeremos el top estados de arrestos por raza, para eso creamos una columna con el promedio de las otras columnas 
df_pregunta_1_c = df_arrestos_estados.copy()[['arrestos_b_2020', 'arrestos_b_2019' , 'arrestos_b_2018']]
df_pregunta_1_c
df_pregunta_1_c['promedio_total_negra'] = df_pregunta_1_c.apply(lambda row: (row.arrestos_b_2020 + row.arrestos_b_2019 + row.arrestos_b_2018) / 3, axis=1)
df_pregunta_1_c[['promedio_total_negra']].sort_values(by=['promedio_total_negra'])
# Out:
#         promedio_total_negra
# estado
# MT                763.666667
# VT                977.000000
# WY               1105.333333
# HI               1491.666667
# ID               1572.000000
# AK               2146.000000
# ME               2294.333333
# NH               2353.000000
# SD               3222.666667
# NM               3392.000000
# WV               3533.000000
# ND               3572.000000
# RI               5590.000000
# UT               5877.666667
# KS              10118.000000
# OR              10158.000000
# NE              12000.000000
# DE              13488.000000
# IA              18419.666667
# MA              20085.333333
# OK              20715.333333
# IL              22849.666667
# WA              23050.333333
# CO              24486.000000
# CT              28055.000000
# AZ              30309.000000
# MS              33902.000000
# IN              34018.666667
# MN              36711.000000
# AR              38207.333333
# KY              39307.000000
# AL              40029.000000
# NV              40105.666667
# PA              47430.666667
# WI              49695.000000
# MO              55489.666667
# OH              60172.333333
# SC              65382.666667
# MD              66315.666667
# NY              66925.666667
# MI              71319.666667
# GA              84174.666667
# TN              92404.000000
# NJ              96487.000000
# LA              96854.333333
# VA             103635.666667
# NC             108940.000000
# CA             159865.666667
# TX             170080.000000

# %% [markdown]
# *Asi entonces podemos concluir que los estados con menor numero de arrestos totales promedio entre gente negra en los ultimos 3 años son:*
# 1. Montana (MT) - 763.666667
# 2. Vermont (VT) - 977.000000
# 3. Wyoming (WY) - 1105.333333
#
# *Y los estados con mayor numero de arrestos totales promedio entre gente negra en los ultimos 3 años son:*
#
# 1. Texas (TX) - 170080.000000
# 2. California (CA) - 159865.666667
# 3. North Carolina (NC) - 108940.000000

# %% [markdown]
# # Pregunta 2
# *¿Cuáles son los estados con el mayor y menor numero de gente negra? (promedio entre 2018 y 2020)*

# %%
df_pregunta_2 =df_final[['porcentaje_b_2020','porcentaje_b_2019','porcentaje_b_2018']]
df_pregunta_2
# Out:
#             porcentaje_b_2020  porcentaje_b_2019  porcentaje_b_2018
# state_abbr
# AK                   0.032007           0.021662           0.029192
# AL                   0.267884           0.265046           0.264550
# AR                   0.147842           0.151993           0.149557
# AZ                   0.049988           0.043195           0.042403
# CA                   0.054321           0.053472           0.053551
# CO                   0.043453           0.037617           0.038198
# CT                   0.111402           0.100310           0.098953
# DE                   0.211202           0.218122           0.213181
# GA                   0.311779           0.313377           0.309220
# HI                   0.014413           0.012211           0.015058
# IA                   0.041708           0.038952           0.033466
# ID                   0.008303           0.006568           0.005408
# IL                   0.140477           0.135889           0.135484
# IN                   0.098529           0.092217           0.092584
# KS                   0.055922           0.054532           0.053540
# NM                   0.019725           0.017145           0.018139
# NV                   0.091128           0.092088           0.086713
# NY                   0.136430           0.140235           0.141159
# OH                   0.124496           0.121570           0.121188
# OK                   0.068800           0.068672           0.070150
# OR                   0.019157           0.017656           0.018074
# PA                   0.108971           0.103574           0.102905
# RI                   0.065662           0.059286           0.056213
# SC                   0.254150           0.262269           0.263337
# SD                   0.022194           0.022084           0.021798
# TN                   0.162404           0.163909           0.165128
# TX                   0.120859           0.116566           0.116040
# UT                   0.010088           0.010336           0.011526
# VA                   0.187174           0.188525           0.185698
# VT                   0.013570           0.011202           0.010989
# WA                   0.040823           0.038080           0.036469
# WI                   0.050736           0.061510           0.061701
# WV                   0.033700           0.032145           0.036124
# WY                   0.010968           0.009597           0.004819
#
#             promedio_black
# state_abbr
# AK                0.027620
# AL                0.265827
# AR                0.149797
# AZ                0.045195
# CA                0.053782
# CO                0.039756
# CT                0.103555
# DE                0.214168
# GA                0.311459
# HI                0.013894
# IA                0.038042
# ID                0.006760
# IL                0.137283
# IN                0.094443
# KS                0.054665
# KY                0.079935
# LA                0.318913
# MA                0.072400
# MD                0.299390
# ME                0.014997
# MI                0.135846
# MN                0.065574
# MO                0.113327
# MS                0.376392
# MT                0.004487
# NC                0.209978
# ND                0.028594
# NE                0.045572
# NH                0.012250
# NJ                0.128336
# NM                0.018337
# NV                0.089977
# NY                0.139274
# OH                0.122418
# OK                0.069207
# OR                0.018296
# PA                0.105150
# RI                0.060387
# SC                0.259919
# SD                0.022025
# TN                0.163814
# TX                0.117821
# UT                0.010650
# VA                0.187133
# VT                0.011920
# WA                0.038457
# WI                0.057983
# WV                0.033990
# WY                0.008461

# %%
df_pregunta_2[['promedio_black']].sort_values(by='promedio_black').tail(3)
# Out:
#             promedio_black
# state_abbr
# GA                0.311459
# LA                0.318913
# MS                0.376392

# %%
df_pregunta_2[['promedio_black']].sort_values(by='promedio_black').head(3)
# Out:
#             promedio_black
# state_abbr
# MT                0.004487
# ID                0.006760
# WY                0.008461

# %% [markdown]
# *Asi entonces podemos concluir que los estados con menor coeficiente de gente negra en los ultimos 3 años son:*
#
# 1. Wyoming (WY) - 0.008461
# 2. Idaho (ID) - 0.006760
# 3. Montana (MT) - 0.004487
#
# *Y los estados con mayor coeficiente de personas negras en los ultimos 3 años son:*
#
# 1. Mississippi (MS) - 0.376392
# 2. Louisiana (LA) - 0.318913
# 3. Georgia (GA) - 0.311459

# %% [markdown]
# # Pregunta 3
#
# ¿Se han mostrado cambios significativos en la cantidad de arrestos por estado entre el 2018 y el 2020?
#
# Nota, los estados tienen sus iniciales respectivas:
#
# Alabama: AL
#
# Alaska: AK
#
# Arizona: AZ
#
# Arkanzas: AR
#
# California: CA
#
# Colorado: CO
#
# Connecticut: CT
#
# Delaware: DE
#
# Distrito de Columbia: DC
#
# Florida: FL
#
# Georgia: GA
#
# Hawaii: HI
#
# Idaho: ID
#
# Illinois: IL
#
# Idiana: IN
#
# Iowa: IA
#
# Kansas: KS
#
# Kentucky: KY
#
# Louisiana: LA
#
# Maine: ME
#
# Maryland:MD
#
# Massachusetts: MA
#
# Michigan: MI
#
# Mississipi: MS
#
# Missouri: MO
#
# Montana: MT
#
# Nebraska: NE
#
# Nevada: NV
#
# New Hampshire: NH
#
# New Jersey: NJ
#
# New York: NY
#
# North Carolina: NC
#
# North Dakota: ND
#
# Ohaio: OH
#
# Oregon: OR
#
# Pennsylvania: PA
#
# Rhode Island: RI
#
# South Carolina: SC
#
# South Dakota: SD
#
# Tennessee: TN
#
# Texas: TX
#
# Utah: UT
#
# Vermont: VT
#
# Virginia: VA
#
# Washington: WA
#
# West Virginia: WV
#
# Wisconsin: WI
#
# Wyoming: WY

# %%
p3_2018 = df_arrestos_totales_estados['arrestos_total_2018']
p3_2019 = df_arrestos_totales_estados['arrestos_total_2019']
p3_2020 = df_arrestos_totales_estados['arrestos_total_2020']
diferencia_18_19 = round(100-((p3_2019*100)/p3_2018))
print('Porcentaje de diferencia por estado:')
diferencia_18_19
# Out:
# Porcentaje de diferencia por estado:
# estado
# AK    10.0
# AL     6.0
# AR     3.0
# AZ     8.0
# CA     4.0
# CO     6.0
# CT     6.0
# DE    -5.0
# GA    50.0
# HI     2.0
# IA   -11.0
# ID     7.0
# IL    91.0
# IN    12.0
# KS   -55.0
# KY     2.0
# LA     8.0
# MA     2.0
# MD    -0.0
# ME     6.0
# MI    10.0
# MN     1.0
# MO     4.0
# MS    -6.0
# MT     5.0
# NC    22.0
# ND     2.0
# NE     2.0
# NH     1.0
# NJ     3.0
# NM    18.0
# NV    -5.0
# NY    12.0
# OH     7.0
# OK     4.0
# OR    -0.0
# PA    60.0
# RI     3.0
# SC    10.0
# SD    -1.0
# TN     5.0
# TX    13.0
# UT     6.0
# VA     2.0
# VT    -8.0
# WA     0.0
# WI     6.0
# WV    13.0
# WY     3.0
# dtype: float64

# %%
print('Los tres estados que disminuyeron sus arrestos entre 2018-2019 considerablemente:')
diferencia_18_19.sort_values().head(3)
# Out:
# Los tres estados que disminuyeron sus arrestos entre 2018-2019 considerablemente:
# estado
# KS   -55.0
# IA   -11.0
# VT    -8.0
# dtype: float64

# %%
print('Los tres estados que aumentaron sus arrestos entre 2018-2019 considerablemente:')
diferencia_18_19.sort_values().tail(3)
# Out:
# Los tres estados que aumentaron sus arrestos entre 2018-2019 considerablemente:
# estado
# GA    50.0
# PA    60.0
# IL    91.0
# dtype: float64

# %%
diferencia_19_20 = round(100-((p3_2020*100)/p3_2019))
print('Porcentaje de diferencia por estado:')
diferencia_19_20
# Out:
# Porcentaje de diferencia por estado:
# estado
# AK     6.0
# AL    97.0
# AR    26.0
# AZ    17.0
# CA    19.0
# CO    28.0
# CT    27.0
# DE    19.0
# GA    11.0
# HI    31.0
# IA    18.0
# ID    22.0
# IL    31.0
# IN    32.0
# KS    12.0
# KY    46.0
# LA    28.0
# MA    27.0
# MD    93.0
# ME    17.0
# MI    25.0
# MN    28.0
# MO    28.0
# MS    35.0
# MT    10.0
# NC    16.0
# ND    11.0
# NE    44.0
# NH    23.0
# NJ    35.0
# NM    44.0
# NV    27.0
# NY    30.0
# OH    29.0
# OK    16.0
# OR    28.0
# PA    98.0
# RI    22.0
# SC    11.0
# SD    18.0
# TN    22.0
# TX    24.0
# UT    20.0
# VA    25.0
# VT    26.0
# WA    22.0
# WI    22.0
# WV    16.0
# WY    22.0
# dtype: float64

# %%
print('Los tres estados que aumentaron sus arrestos entre 2018-2019 menos de todos:')
diferencia_19_20.sort_values().head(3)
# Out:
# Los tres estados que aumentaron sus arrestos entre 2018-2019 menos de todos:
# estado
# AK     6.0
# MT    10.0
# ND    11.0
# dtype: float64

# %%
print('Los tres estados que aumentaron sus arrestos entre 2018-2019 considerablemente:')
diferencia_19_20.sort_values().tail(3)
# Out:
# Los tres estados que aumentaron sus arrestos entre 2018-2019 considerablemente:
# estado
# MD    93.0
# AL    97.0
# PA    98.0
# dtype: float64

# %% [markdown]
# # Cual es la comparacion entre el numero de arrestos y de personas a nivel nacional en cada año?

# %%
# arrest_white - arrest_black - arrest_total 
arrestos = df_final[['arrestos_w_2020',	'arrestos_b_2020','arrestos_total_2020','arrestos_w_2019','arrestos_b_2019','arrestos_total_2019','arrestos_w_2018','arrestos_b_2018', 'arrestos_total_2018']]
arrestos['usa'] = ['usa' for x in range(len(arrestos))]
arrestos_usa = arrestos.groupby('usa').sum()
arrestos_usa
# Out:
# C:\Users\jcabe\AppData\Local\Temp/ipykernel_7512/827312489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arrestos['usa'] = ['usa' for x in range(len(arrestos))]
#      arrestos_w_2020  arrestos_b_2020  arrestos_total_2020  arrestos_w_2019  \
# usa
# usa        3770521.0        1409344.0            5179865.0        5231441.0
#
#      arrestos_b_2019  arrestos_total_2019  arrestos_w_2018  arrestos_b_2018  \
# usa
# usa        2050058.0            7281499.0        5796917.0        2327832.0
#
#      arrestos_total_2018
# usa
# usa            8124749.0

# %%
arrestos_w_usa = arrestos_usa[['arrestos_w_2018','arrestos_w_2019','arrestos_w_2020']]
arrestos_w_usa
# Out:
#      arrestos_w_2018  arrestos_w_2019  arrestos_w_2020
# usa
# usa        5796917.0        5231441.0        3770521.0

# %%
arrestos_b_usa = arrestos_usa[['arrestos_b_2018','arrestos_b_2019','arrestos_b_2020']]
arrestos_b_usa
# Out:
#      arrestos_b_2018  arrestos_b_2019  arrestos_b_2020
# usa
# usa        2327832.0        2050058.0        1409344.0

# %%
arrestos_total_usa = arrestos_usa[['arrestos_total_2018','arrestos_total_2019','arrestos_total_2020']]
arrestos_total_usa
# Out:
#      arrestos_total_2018  arrestos_total_2019  arrestos_total_2020
# usa
# usa            8124749.0            7281499.0            5179865.0

# %%
X = np.arange(3)

list(arrestos_w_usa.loc['usa'].values)

anos = ['2018', '2019', '2020']
X_axis = np.arange(len(anos))


plt.bar(X  - 0.25, arrestos_w_usa.loc['usa'].values ,width= 0.25, label='blancos')
plt.bar(X + 0,  arrestos_b_usa.loc['usa'].values, width= 0.25, label='negros')
plt.bar(X + 0.25,  arrestos_total_usa.loc['usa'].values, width= 0.25, label='total')

plt.xticks(X_axis, anos)

plt.xlabel('Años')
plt.ylabel('Millones de arrestos')
plt.title("Número de arrestos por raza")
plt.legend()
plt.show();

# %% [markdown]
# # ¿Existen grupos que tengan relacion basados en la informacion que tenemos?

# %%
scaler = StandardScaler()
data = df_final.drop(columns=['arrestos_w_2020', 'arrestos_b_2020', 'arrestos_total_2020',
       'arrestos_w_2019', 'arrestos_b_2019', 'arrestos_total_2019',
       'arrestos_w_2018', 'arrestos_b_2018', 'arrestos_total_2018',
       'state_name', 'poblacion_w_2020', 'poblacion_b_2020',
       'total_2020', 'poblacion_w_2019', 'poblacion_b_2019', 'total_2019',
       'poblacion_w_2018', 'poblacion_b_2018', 'total_2018'])
scaler_fit = scaler.fit_transform(data)

# %%
inertia = []
kmax = 10
for i in range(1,kmax):
    kmeans = KMeans(n_clusters = i, n_init = 10)
    kncl = kmeans.fit(scaler_fit)
    print(kncl.inertia_)
    
    inertia.append(kncl.inertia_)
# Out:
# 588.0
# 278.2050762386303
# 185.53920420026418
# 113.98445457361987
# 92.64235373544741
# 74.5320304426191
# 58.422372012764434
# 47.25267289445677
# 37.70439300910297

# %%
f, ax = plt.subplots(1,1, figsize=(20,10))

ax.plot(range(1,kmax),inertia,marker='o',ls='--')
ax.set_xlabel('N Clusters')
ax.set_ylabel('Inercia de clusters')
ax.set_title('K-means - Método del codo')

for i in range(1,len(inertia)):
    delta=(-inertia[i-1]+inertia[i])/inertia[i-1]*100
    ax.text(i+1.1,inertia[i],'%.2f'%delta+'%',color='b')
ax.set_xticks(range(1,kmax))

plt.show()

# %%
# 3
kmeans = KMeans(n_clusters = 4)
kncl = kmeans.fit(scaler_fit)

data['labels'] = kncl.labels_
df_mapa = pd.merge(data, states, left_on='state_abbr', right_on='STUSPS').set_index('STUSPS')

data_mapa = gpd.GeoDataFrame(df_mapa)

fig = plt.figure(figsize=(15,11))
ax = fig.add_subplot(111)
data_mapa.plot(column= 'labels', ax=ax, legend=True, categorical=True);
ax.set_title('K-means 4 - Mapa estados unidos en base arrestos y porcetaje de poblacion')

ax.set_xlim(-185, -65);

for i in data_mapa.index:
    plt.text(data_mapa.loc[i, 'geometry'].centroid.x , data_mapa.loc[i, 'geometry'].centroid.y , i)
    
plt.show()

# %%
kmeans = data.groupby('labels').mean()
kmeans.T
# Out:
# labels                            0         1         2         3
# porcentaje_arresto_w_2020  0.705101  0.892208  0.507093  0.817476
# porcentaje_arresto_w_2019  0.712210  0.890659  0.505668  0.824117
# porcentaje_arresto_w_2018  0.715570  0.894649  0.503703  0.831175
# porcentaje_arresto_b_2020  0.294899  0.107792  0.492907  0.182524
# porcentaje_arresto_b_2019  0.287790  0.109341  0.494332  0.175883
# porcentaje_arresto_b_2018  0.284430  0.105351  0.496297  0.168825
# porcentaje_w_2020          0.728143  0.822786  0.581125  0.426913
# porcentaje_w_2019          0.732411  0.824673  0.588342  0.423782
# porcentaje_w_2018          0.735514  0.826200  0.590881  0.426599
# porcentaje_b_2020          0.101242  0.028068  0.247823  0.054634
# porcentaje_b_2019          0.099405  0.025990  0.246188  0.050906
# porcentaje_b_2018          0.099103  0.025308  0.244752  0.051585

# %%
import seaborn as sn

sn.heatmap(kmeans.T, vmin=0, vmax= 1, annot= True);
